# %%
import requests
from PIL import Image
from transformers import BlipProcessor, BlipForConditionalGeneration
import os
import torch
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# ! possibly change dir_path

batch_size = 30
dir_path = r'C:\Users\FMari\TinkoffSirius\images'

# %%
class IC_model():
    """
    Класс, который принимает на вход изображения
    и выдает описания к ним
    """
    def __init__(self):
        self.processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-large")
        self.model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-large", torch_dtype=torch.float16)
        
        self.device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        self.model.to(self.device)
        self.model.eval()
        

    def predict(self, img_paths, conditional=False, texts=None) -> str:
        """
        :img_paths: list(str) - путь, где лежит картинка
        :conditional: bool, optional - с условием или без
        :texts: list(str), optional - текст, на который должен быть ориентирован ответ
        """   
        
        images = [Image.open(path).convert(mode="RGB") for path in img_paths]
        if conditional:
            inputs = self.processor(images, 
                                    text=texts, 
                                    return_tensors="pt").to(self.device, torch.float16)
        else:
            inputs = self.processor(images, 
                                    return_tensors="pt").to(self.device, torch.float16)

        outs = self.model.generate(**inputs)
        answers = self.processor.batch_decode(outs, skip_special_tokens=True)
        
        return answers

# %%
model = IC_model()

# %% [markdown]
# Создадим массив путей к картинкам, чтобы было удобнее собирать по батчам

# %%
img_paths = []

for chain_id in os.listdir(dir_path):
    chain_dir = os.path.join(dir_path, chain_id)
    
    for hotel_id in os.listdir(chain_dir):
        hotel_dir = os.path.join(chain_dir, hotel_id)
        
        for source in os.listdir(hotel_dir):
            path = os.path.join(hotel_dir, source)
            
            for img in os.listdir(path):
                img_paths.append(os.path.join(path, img))

# %%
# сохраним его

with open(r'img_paths.txt', 'w') as f:
    for path in img_paths:
        f.write("%s\n" % path)
    print('Done')
# Out:
# Done

# %%
captions = np.empty(len(img_paths), dtype="<U100")

# %%
for idx in range(0, len(img_paths), batch_size):
    stop = min(len(img_paths), idx+batch_size)
    preds = np.array(model.predict(img_paths[idx:stop]))
    captions[idx:stop] = preds
    
    if idx % 100 == 0:
        print(idx)
# Out:
# 0
# 300
# 600
# 900
# 1200
# 1500
# 1800
# 2100
# 2400
# 2700
# 3000
# 3300
# 3600
# 3900
# 4200
# 4500
# 4800
# 5100
# 5400
# 5700
# 6000
# 6300
# 6600
# 6900
# 7200
# 7500
# 7800
# 8100
# 8400
# 8700
# 9000
# 9300
# 9600
# 9900
# 10200
# 10500
# 10800
# 11100
# 11400
# 11700
# 12000
# 12300
# 12600
# 12900
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[28], line 3
#       1 for idx in range(0, len(img_paths), batch_size):
#       2     stop = min(len(img_paths), idx+batch_size)
# ----> 3     preds = np.array(model.predict(img_paths[idx:stop]))
#       4     captions[idx:stop] = preds
#       6     if idx % 100 == 0:
#
# Cell In[2], line 24, in IC_model.predict(self, img_paths, conditional, texts)
#      17 def predict(self, img_paths, conditional=False, texts=None) -> str:
#      18     """
#      19     :img_paths: list(str) - путь, где лежит картинка
#      20     :conditional: bool, optional - с условием или без
#      21     :texts: list(str), optional - текст, на который должен быть ориентирован ответ
#      22     """
# ---> 24     images = [Image.open(path).convert(mode="RGB") for path in img_paths]
#      25     if conditional:
#      26         inputs = self.processor(images,
#      27                                 text=texts,
#      28                                 return_tensors="pt").to(self.device, torch.float16)
#
# Cell In[2], line 24, in <listcomp>(.0)
#      17 def predict(self, img_paths, conditional=False, texts=None) -> str:
#      18     """
#      19     :img_paths: list(str) - путь, где лежит картинка
#      20     :conditional: bool, optional - с условием или без
#      21     :texts: list(str), optional - текст, на который должен быть ориентирован ответ
#      22     """
# ---> 24     images = [Image.open(path).convert(mode="RGB") for path in img_paths]
#      25     if conditional:
#      26         inputs = self.processor(images,
#      27                                 text=texts,
#      28                                 return_tensors="pt").to(self.device, torch.float16)
#
# File ~\miniconda3\envs\torch_env\lib\site-packages\PIL\Image.py:921, in Image.convert(self, mode, matrix, dither, palette, colors)
#     873 def convert(
#     874     self, mode=None, matrix=None, dither=None, palette=Palette.WEB, colors=256
#     875 ):
#     876     """
#     877     Returns a converted copy of this image. For the "P" mode, this
#     878     method translates pixels through the palette.  If mode is
#    (...)
#     918     :returns: An :py:class:`~PIL.Image.Image` object.
#     919     """
# --> 921     self.load()
#     923     has_transparency = self.info.get("transparency") is not None
#     924     if not mode and self.mode == "P":
#     925         # determine default mode
#
# File ~\miniconda3\envs\torch_env\lib\site-packages\PIL\ImageFile.py:279, in ImageFile.load(self)
#     275 self.fp = None
#     277 if not self.map and not LOAD_TRUNCATED_IMAGES and err_code < 0:
#     278     # still raised if decoder fails to return anything
# --> 279     raise_oserror(err_code)
#     281 return Image.Image.load(self)
#
# File ~\miniconda3\envs\torch_env\lib\site-packages\PIL\ImageFile.py:71, in raise_oserror(error)
#      69 if not message:
#      70     message = f"decoder error {error}"
# ---> 71 raise OSError(message + " when reading image file")
#
# OSError: unrecognized data stream contents when reading image file

# %%
made_captions = captions[:13170]
np.save('made_captions', made_captions)

# %% [markdown]
# # TF-IDF #

# %%
# индекс определяет на каком месте в path.split('\\') находится папка train с изображениями
IDX0 = 0  

for i, path_part in enumerate(img_paths[0].split('\\')):
    if path_part == 'train':
        IDX0 = i

# %% [markdown]
# Сгруппируем созданные описания по отелям (словарь *book*) и по сетям отелей (массив *capts_for_chain*)

# %%
book = {}
capts_for_chain = np.zeros(85, dtype="<U10000")

for i in range(size):
    hotel = int(img_paths[i].split('\\')[IDX0+2])
    chain = int(img_paths[i].split('\\')[IDX0+1]) + 1
    capts_for_chain[chain] += ' ' + made_captions[i] + ' '
    
    try:
        book[hotel] += ' ' + made_captions[i] + ' '
    except:
        book[hotel] = ' ' + made_captions[i] + ' '

# %%
vectorizer = TfidfVectorizer()
tf_idf = vectorizer.fit_transform(values)
vocab = vectorizer.get_feature_names_out()

# %% [markdown]
# Оставим только слова с высоким tf-idf, которые характеризуют отель

# %%
new_comms = []
for i in range(len(values)):
    idxs = tf_idf[i, :]
    non_zero_idxs = idxs.nonzero()
    new_comms.append([])
    for j in non_zero_idxs[1]:
        value = idxs[0, j]
        if value > 0.3 and value < 0.9:  # убираем слова c плохим tf-idf
            new_comms[i].append(vocab[j])

# %%
new_comms
# Out:
# [['pillow', 'brown', 'blanket', 'bed'],
#  ['table', 'couch', 'living'],
#  ['lamp', 'lot', 'bedroom', 'of'],
#  ['mirror', 'bathtub', 'sink', 'bathroom'],
#  ['sheets', 'mirror', 'arafed', 'pillows'],
#  ['corner', 'cabinet', 'doorway'],
#  ['bathtub', 'shower'],
#  ['pillows', 'blanket'],
#  ['bag', 'suitcase', 'it', 'on'],
#  ['taking', 'shining', 'light', 'purple'],
#  ['above', 'painting', 'and'],
#  ['fireplace'],
#  ['toilet', 'sink', 'shower', 'bathroom'],
#  ['lamp', 'couch'],
#  ['sheets', 'pillows', 'in'],
#  ['lamp', 'table', 'couch', 'living'],
#  ['checkered', 'picture'],
#  ['herself', 'woman', 'taking'],
#  ['to', 'next', 'sitting', 'shower'],
#  ['small', 'toilet', 'bathtub', 'bathroom'],
#  ['small', 'toilet', 'bathtub', 'bathroom'],
#  ['four'],
#  ['small', 'couch', 'television'],
#  ['bedroom', 'it', 'desk'],
#  ['toilet', 'sink', 'shower', 'bathroom'],
#  ['in', 'desk', 'room', 'bed'],
#  ['boy', 'little'],
#  ['curtains', 'window'],
#  ['freezer', 'hallway', 'refrigerator'],
#  ['blankets', 'lot', 'the'],
#  ['small', 'couch', 'living'],
#  ['cover', 'it', 'sink'],
#  ['picture', 'the'],
#  ['top', 'mattress', 'bunk'],
#  ['door', 'small', 'in'],
#  ['made', 'neatly'],
#  ['glass', 'sliding', 'door'],
#  ['curtain', 'blanket'],
#  ['glass', 'door', 'bathtub'],
#  ['comforter', 'white'],
#  ['hotel', 'in', 'desk', 'room', 'bed'],
#  ['tv', 'shower', 'is'],
#  ['lamp', 'couch', 'chair'],
#  ['small', 'desk'],
#  ['sheet', 'it', 'on'],
#  ['pictures', 'two', 'beds', 'are'],
#  ['sheets', 'arafed', 'pillows', 'bed'],
#  ['middle', 'ladder', 'view', 'of'],
#  ['it', 'bathtub', 'sink', 'bathroom'],
#  ['sitting', 'woman'],
#  ['green', 'beds', 'are'],
#  ['horse', 'standing'],
#  ['green', 'arafed', 'blanket', 'red'],
#  ['brick', 'of', 'couch'],
#  ['blue', 'wall', 'comforter'],
#  ['sheets', 'table', 'couch', 'living'],
#  ['two', 'beds', 'are'],
#  ['rack', 'towels'],
#  ['shelf', 'tv', 'small', 'sitting'],
#  ['post', 'four', 'pillows', 'bed'],
#  ['towels', 'sheets', 'with'],
#  ['two', 'beds', 'it', 'desk'],
#  ['maker', 'coffee'],
#  ['corner', 'cabinet'],
#  ['two', 'beds', 'are'],
#  ['it', 'on', 'pillows', 'comforter', 'white'],
#  ['lamp', 'table', 'television', 'comforter', 'and', 'is'],
#  ['laying', 'person'],
#  ['computer', 'desk'],
#  ['window', 'chair'],
#  ['carpet', 'blue'],
#  ['striped', 'cat', 'pictures'],
#  ['window', 'lamp'],
#  ['striped'],
#  ['toilet', 'mirror', 'sink', 'bathroom'],
#  ['counter', 'shelf', 'top'],
#  ['stairs', 'top', 'of', 'the'],
#  ['small', 'chair', 'and', 'is'],
#  ['small', 'bathtub', 'pillows', 'in', 'comforter'],
#  ['mounted', 'above'],
#  ['table', 'couch', 'living', 'television', 'chair'],
#  ['mural', 'laptop', 'on'],
#  ['wallpaper', 'pink', 'leading', 'to', 'doorway'],
#  ['microwave', 'black', 'refrigerator'],
#  ['striped', 'curtain'],
#  ['bedroom', 'bed'],
#  ['wooden', 'leading', 'computer'],
#  ['black', 'suitcase', 'white', 'blanket'],
#  ['design', 'fabric', 'piece', 'holding', 'monitor'],
#  ['blue', 'pillow'],
#  ['lamp', 'couch'],
#  ['in', 'desk', 'room', 'bed'],
#  ['it', 'sink', 'shower', 'bathroom'],
#  ['table', 'couch', 'and'],
#  ['colorful', 'comforter'],
#  ['blue', 'pillow', 'blanket'],
#  ['shelf', 'towels', 'the'],
#  ['mirror', 'desk', 'chair', 'and', 'is'],
#  ['two', 'beds', 'painting', 'desk'],
#  ['blue', 'headboard', 'pillows', 'white'],
#  ['toilet', 'it', 'sink', 'bathroom'],
#  ['small', 'corner'],
#  ['beds', 'are', 'painting', 'wall', 'the'],
#  ['up', 'close', 'glass', 'door'],
#  ['mirror', 'bathtub', 'desk'],
#  ['window', 'chair'],
#  ['window', 'small'],
#  ['small', 'desk', 'chair'],
#  ['view', 'bedroom', 'picture'],
#  ['pink', 'brick'],
#  ['backpack', 'laptop', 'it', 'on', 'pillow'],
#  ['headboard', 'black', 'bathtub', 'blanket'],
#  ['river', 'view', 'of'],
#  ['refrigerators', 'microwave', 'small'],
#  ['painted'],
#  ['it', 'sink', 'shower', 'bathroom'],
#  ['hotel', 'television', 'chair', 'red'],
#  ['large', 'mattress'],
#  ['stand', 'night', 'comforter'],
#  ['blanket', 'red'],
#  ['person', 'sitting'],
#  ['stand', 'night'],
#  ['dark', 'lit', 'dimly', 'bedroom'],
#  ['toilet', 'mirror', 'it', 'bathroom'],
#  ['stand', 'night', 'pillow'],
#  [],
#  ['of', 'picture', 'it', 'on', 'blanket'],
#  ['bear', 'teddy', 'sitting'],
#  ['oven', 'lit', 'dimly', 'microwave'],
#  ['yellow', 'sheets'],
#  ['arafed', 'hotel', 'pillows', 'blanket'],
#  ['curtain', 'bathtub', 'shower'],
#  ['striped', 'brown', 'comforter'],
#  ['curtain', 'shower', 'red'],
#  ['himself'],
#  ['book', 'reading', 'sitting', 'man'],
#  ['ottoman', 'painting', 'living'],
#  ['small', 'table'],
#  ['sheets', 'arafed', 'hotel', 'pillows'],
#  ['and', 'is'],
#  ['two', 'window', 'beds', 'are', 'desk'],
#  ['two', 'beds', 'are', 'wall', 'the', 'television'],
#  ['mirror', 'bathtub', 'television', 'desk'],
#  ['carpet', 'blue', 'red'],
#  ['tv', 'desk', 'chair'],
#  ['curtains', 'window'],
#  ['hanging', 'towel'],
#  ['laptop', 'beds', 'are', 'the'],
#  ['two', 'beds', 'are', 'lamp', 'on', 'hotel'],
#  ['large', 'window', 'desk'],
#  ['pillows', 'white'],
#  ['two', 'beds', 'are', 'bathtub', 'hotel'],
#  ['from', 'city', 'view'],
#  ['wine', 'bottle'],
#  ['street', 'view'],
#  ['paper', 'of'],
#  ['lamps', 'black', 'arafed', 'and'],
#  ['two', 'window', 'beds', 'are', 'hotel'],
#  ['two', 'window', 'beds', 'are', 'hotel'],
#  ['leading', 'to', 'doorway', 'bedroom'],
#  ['large', 'tv', 'screen', 'flat'],
#  ['painting', 'arafed', 'wall', 'the', 'blanket'],
#  ['from', 'hallway', 'view', 'of'],
#  [],
#  ['yellow', 'hotel'],
#  ['two', 'window', 'beds', 'are', 'hotel'],
#  ['side', 'either', 'lamps', 'red'],
#  ['pink', 'sheet'],
#  ['tile', 'floor', 'red'],
#  ['microwave', 'laptop', 'kitchen'],
#  ['stairs', 'from', 'top', 'of', 'the'],
#  [],
#  ['pillows', 'shower', 'blanket'],
#  ['in', 'and', 'bed', 'is'],
#  ['colorful'],
#  ['shutters', 'rug', 'middle', 'green'],
#  ['tub', 'toilet', 'it', 'sink'],
#  ['two', 'beds', 'are', 'blanket', 'red'],
#  ['striped', 'glass', 'fireplace'],
#  ['green', 'headboard', 'brown', 'blanket'],
#  ['white', 'and', 'blanket', 'red', 'bed'],
#  ['curtains', 'table'],
#  ['hotel', 'in', 'television', 'room', 'bed'],
#  ['yellow', 'television', 'desk', 'blanket'],
#  ['canopy', 'window'],
#  ['at', 'parking', 'balcony', 'from', 'lot'],
#  ['fan', 'beds', 'are'],
#  ['linen', 'hotel'],
#  ['city', 'is'],
#  ['hotel', 'white', 'and', 'is'],
#  ['colorful', 'blanket'],
#  ['picture', 'chair', 'and', 'bed', 'is'],
#  ['green', 'headboard', 'brown', 'blanket'],
#  ['large', 'couch', 'hotel'],
#  ['corner', 'the', 'comforter', 'chair'],
#  ['hotel', 'pillows', 'white', 'blanket'],
#  ['bag', 'it', 'on'],
#  ['board', 'foot', 'headboard'],
#  ['hotel', 'desk', 'chair'],
#  ['wallpapered'],
#  ['side', 'bedroom'],
#  ['sitting', 'floor', 'bag', 'suitcase'],
#  ['tub', 'colorful', 'curtain', 'blanket'],
#  ['chair', 'blanket'],
#  ['striped', 'computer'],
#  ['two', 'window', 'beds', 'are', 'sink'],
#  ['lamps', 'arafed', 'bathtub', 'and', 'red'],
#  ['chair', 'red'],
#  ['suitcase', 'blanket'],
#  ['small', 'television'],
#  ['green', 'brown', 'and', 'with'],
#  ['pillow', 'desk'],
#  ['two', 'pillows', 'blanket'],
#  ['that', 'on', 'television', 'is'],
#  ['small', 'toilet', 'sink', 'bathroom'],
#  ['black', 'chair', 'and', 'blanket'],
#  ['mirror', 'lamp', 'in', 'and', 'is'],
#  ['floral', 'middle', 'cabinet'],
#  ['painting', 'arafed'],
#  ['wooden', 'headboard', 'blanket'],
#  ['mirror', 'it', 'sink', 'bathroom'],
#  ['rack', 'hanging', 'towel'],
#  ['green', 'pillows', 'blanket'],
#  ['striped'],
#  ['striped', 'floor'],
#  ['small', 'toilet', 'sink', 'bathroom'],
#  ['brown', 'comforter', 'blanket'],
#  ['dining', 'staircase', 'mirror'],
#  ['small', 'toilet', 'bathtub', 'bathroom'],
#  ['pillow', 'brown', 'blanket', 'red'],
#  ['laptop', 'it', 'blanket'],
#  ['canopy', 'mounted'],
#  ['mirror', 'in', 'room', 'bed'],
#  ['made', 'neatly', 'bed'],
#  [],
#  ['pattern', 'up', 'close', 'striped', 'of'],
#  ['two', 'window', 'beds', 'are', 'hotel'],
#  ['stand', 'night', 'made', 'neatly'],
#  ['mirror', 'sink', 'shower', 'bathroom'],
#  ['blankets', 'red'],
#  ['bag', 'it', 'on'],
#  ['tv', 'table'],
#  ['toilet', 'it', 'sink', 'shower', 'bathroom'],
#  ['chairs', 'table', 'coffee', 'with'],
#  ['view', 'of'],
#  ['small', 'lamp', 'bathtub'],
#  ['comforter', 'chair', 'white'],
#  ['small', 'toilet', 'sink', 'bathroom'],
#  ['stand', 'bathtub', 'bathroom'],
#  ['rug', 'hallway', 'green', 'cabinet'],
#  ['black', 'chair', 'blanket', 'red'],
#  ['pillows', 'comforter', 'white'],
#  ['comforter', 'chair', 'white'],
#  ['floral', 'pink', 'curtain'],
#  ['this', 'dining', 'small', 'kitchen'],
#  ['suitcase', 'red'],
#  ['hallway', 'standing', 'woman'],
#  ['wooden', 'shower'],
#  ['computer'],
#  ['front', 'standing', 'man'],
#  ['mirror', 'it', 'in', 'sink', 'chair', 'and', 'is'],
#  ['lamps', 'and', 'red'],
#  ['window', 'in', 'room'],
#  ['comforter', 'chair', 'white'],
#  ['headboard', 'brown', 'comforter'],
#  ['table', 'couch', 'living'],
#  ['door', 'chair'],
#  ['table', 'couch', 'living', 'shower'],
#  ['bridge', 'large', 'the'],
#  ['headboard', 'brown', 'blanket'],
#  ['computer', 'suitcase', 'brown'],
#  ['floral', 'laptop', 'comforter'],
#  ['sheet', 'small', 'headboard', 'black'],
#  ['curtain', 'headboard', 'shower', 'brown'],
#  ['it', 'on', 'brown', 'blanket'],
#  ['wooden', 'cover', 'yellow'],
#  ['bathtub', 'sink', 'bathroom'],
#  ['made', 'neatly'],
#  ['couch', 'in', 'room', 'bed'],
#  ['gold'],
#  ['it', 'with', 'is'],
#  ['lamps', 'two', 'beds', 'are'],
#  ['sinks'],
#  ['two', 'beds', 'are', 'on', 'hotel', 'television'],
#  ['oven', 'microwave'],
#  ['and', 'is'],
#  ['in', 'with'],
#  ['each', 'with'],
#  ['kitchen', 'chairs', 'white'],
#  ['it', 'bathtub', 'sink', 'bathroom'],
#  ['it', 'on', 'pillows', 'blanket'],
#  ['over', 'curtain', 'hanging'],
#  ['painting', 'chairs', 'table', 'couch', 'living'],
#  ['headboard', 'table', 'brown', 'bed'],
#  ['two', 'beds', 'are', 'red'],
#  ['ottoman', 'door', 'in', 'bathroom'],
#  ['three', 'beds', 'are'],
#  ['coat', 'door', 'spread', 'red'],
#  ['screen', 'flat', 'curtain'],
#  ['dresser', 'two', 'beds', 'television'],
#  ['striped', 'arafed', 'blanket'],
#  ['plaid', 'couch', 'television'],
#  ['black', 'pillow', 'blanket', 'red'],
#  ['sheets', 'arafed', 'hotel', 'pillows'],
#  ['araffe', 'pink', 'sitting'],
#  ['small', 'toilet', 'bathtub', 'bathroom'],
#  ['bathtub'],
#  ['glass'],
#  ['hotel', 'in', 'desk', 'room', 'bed'],
#  ['in', 'white', 'and', 'is'],
#  ['top', 'sheet', 'of'],
#  ['brown', 'blanket'],
#  ['computer', 'desk'],
#  ['lamps', 'black', 'comforter'],
#  ['pillow', 'blanket', 'red'],
#  ['paintings', 'laptop', 'chair'],
#  ['clothes', 'pile'],
#  ['black', 'comforter', 'bed'],
#  ['picture', 'wall', 'the', 'blanket', 'red'],
#  ['quilt', 'bedspread', 'blue', 'arafed'],
#  ['in', 'and'],
#  ['small', 'sheets', 'pillows', 'in'],
#  ['mirror', 'sink', 'shower', 'bathroom'],
#  ['two', 'corner', 'the', 'pillows', 'desk'],
#  ['large', 'television'],
#  ['ottoman', 'fireplace', 'living', 'brown'],
#  ['shower'],
#  ['laptop', 'it', 'on'],
#  ['fan'],
#  [],
#  ['towels', 'toilet', 'sink'],
#  ['messy', 'kitchen', 'refrigerator'],
#  ['stall', 'arafed'],
#  ['sheet', 'it', 'on'],
#  ['with'],
#  ['blue', 'middle', 'sitting', 'suitcase', 'pillow'],
#  ['rug', 'brown', 'blanket'],
#  ['is'],
#  ['two', 'beds', 'are', 'sheets', 'hotel'],
#  ['framed', 'pictures', 'bedroom'],
#  ['paper', 'sheet', 'standing', 'woman'],
#  ['beds', 'are', 'chairs', 'table'],
#  ['suitcase', 'bathtub'],
#  ['couch', 'blanket', 'red', 'bed'],
#  ['arafed', 'pillows', 'brown', 'blanket'],
#  ['kitchen', 'with'],
#  ['crib', 'baby', 'carpet', 'chair'],
#  ['lamps', 'red'],
#  ['pizza', 'four', 'chairs', 'table'],
#  ['two', 'beds', 'are', 'lamp', 'on', 'hotel'],
#  ['blue', 'comforter', 'blanket'],
#  ['ottoman', 'black', 'white'],
#  ['two', 'beds', 'are', 'sheets', 'pillows'],
#  ['window', 'table'],
#  ['small', 'toilet', 'sink', 'bathroom'],
#  ['is'],
#  ['leading', 'to', 'bedroom'],
#  ['yellow'],
#  ['marble', 'cover', 'mirror'],
#  ['white'],
#  ['in', 'desk', 'room', 'bed'],
#  ['mirror', 'in', 'television', 'room'],
#  ['headboard', 'brown', 'blanket'],
#  ['food', 'plate', 'tray'],
#  ['door', 'picture'],
#  ['table'],
#  ['pictures', 'living'],
#  ['two', 'lamp', 'it', 'on', 'pillows'],
#  ['table', 'couch', 'living', 'television'],
#  ['open', 'shutters', 'curtain'],
#  ['bird', 'quilt', 'small'],
#  ['black', 'picture', 'comforter', 'white'],
#  ['in', 'television', 'room', 'bed'],
#  ['animal', 'stuffed'],
#  ['photo', 'crowded', 'people', 'many', 'street'],
#  ['in', 'desk', 'chair', 'and', 'is'],
#  ['headboard', 'arafed', 'shower', 'red'],
#  ['people', 'sitting'],
#  ['stand', 'night', 'pillows'],
#  ['it', 'pillows', 'comforter', 'desk', 'bed'],
#  ['lamp', 'comforter', 'desk', 'white', 'with'],
#  ['ottoman', 'arafed', 'couch', 'living'],
#  ['people', 'standing'],
#  ['lamp', 'chair'],
#  ['two', 'beds', 'are', 'lamp', 'on', 'hotel'],
#  ['picture', 'wall', 'the', 'blanket', 'red'],
#  ['pillows', 'red'],
#  ['curtain', 'toilet', 'sink', 'shower'],
#  ['person', 'standing'],
#  ['two', 'beds', 'are', 'sheets', 'hotel'],
#  ['toilet', 'towel', 'sink', 'bathroom'],
#  ['tub', 'curtain', 'bathroom'],
#  ['brown', 'and'],
#  ['large', 'window', 'chair'],
#  ['man', 'on', 'hotel'],
#  ['window', 'it'],
#  ['lamp'],
#  [],
#  ['clothes', 'bunch', 'hanging'],
#  ['glass', 'chairs', 'table', 'living'],
#  ['umbrella', 'carpeted', 'hallway'],
#  ['sheets', 'arafed', 'hotel', 'pillows'],
#  ['in'],
#  ['hallway', 'mirror', 'sink'],
#  ['cover', 'black', 'pillow', 'white'],
#  ['rack', 'towel'],
#  ['black', 'pillow', 'brown', 'blanket'],
#  ['made', 'neatly', 'light'],
#  ['view', 'doorway', 'mirror', 'bathroom'],
#  ['shower', 'brown', 'blanket'],
#  ['tile', 'floor', 'black'],
#  ['small', 'fireplace'],
#  ['chairs', 'couch', 'living', 'television'],
#  ['red'],
#  ['couch', 'in', 'desk', 'chair', 'room'],
#  ['leading', 'to', 'doorway', 'bedroom'],
#  ['counter', 'towels', 'beds', 'are', 'lamp', 'on'],
#  ['tv', 'screen', 'flat', 'picture'],
#  ['stuff', 'lot'],
#  ['sheets', 'arafed', 'hotel', 'pillows'],
#  ['mounted', 'wall', 'the'],
#  ['green', 'lamp', 'desk', 'blanket', 'with'],
#  ['lamps', 'two', 'beds', 'are'],
#  ['plaid', 'toilet'],
#  ['sitting', 'floor', 'bag'],
#  ['checkered'],
#  ['baby', 'above'],
#  ['television', 'comforter', 'white'],
#  ['headboard', 'brown', 'blanket'],
#  ['hotel', 'in'],
#  ['flower', 'large', 'above'],
#  ['small', 'television', 'desk'],
#  ['lamps', 'blanket'],
#  ['black', 'comforter', 'blanket'],
#  ['two', 'beds', 'refrigerator', 'television'],
#  ['bench', 'black'],
#  ['bedroom', 'it', 'chair'],
#  ['blue', 'pillow', 'blanket'],
#  ['crowd', 'case', 'head', 'board'],
#  ['ceiling', 'from', 'hanging'],
#  ['green', 'spread', 'bed'],
#  ['arafed', 'pillows', 'blanket'],
#  ['comforter', 'chair', 'white'],
#  ['door', 'sink', 'white'],
#  ['two', 'beds', 'are', 'hotel', 'desk', 'chair'],
#  ['rack', 'window', 'towel', 'bathtub'],
#  ['sheets', 'pillows', 'white'],
#  ['dresser', 'on', 'television'],
#  ['mural', 'wall'],
#  ['purple'],
#  ['door', 'hallway', 'picture'],
#  ['suitcase', 'it', 'on'],
#  ['in'],
#  ['staircase', 'from', 'top', 'of'],
#  ['toilet', 'it', 'bathtub', 'bathroom'],
#  ['piano', 'canopy', 'balcony', 'chairs'],
#  ['three', 'gold'],
#  ['ironing', 'board'],
#  ['headboard', 'brown'],
#  ['glove', 'baseball', 'couch', 'living'],
#  ['framed', 'pictures', 'floor', 'the', 'comforter'],
#  ['bedroom', 'desk', 'with'],
#  ['framed', 'dresser', 'pictures', 'green'],
#  ['cover', 'corner', 'bed'],
#  ['table', 'television'],
#  ['checkered', 'wall'],
#  ['sheets', 'pillows', 'in', 'bed'],
#  ['dresser', 'green', 'in'],
#  ['toilet', 'it', 'sink', 'bathroom'],
#  ['small', 'toilet', 'bathtub', 'bathroom'],
#  ['small', 'toilet', 'sink', 'bathroom'],
#  ['window', 'hotel'],
#  ['small', 'and'],
#  ['floral'],
#  ['striped', 'white', 'bed'],
#  ['black', 'mirror', 'and', 'blanket'],
#  ['walls', 'blue'],
#  ['television', 'desk', 'room', 'bed'],
#  ['small', 'mirror'],
#  ['two', 'beds', 'in', 'television', 'desk', 'room'],
#  ['case', 'pillow'],
#  ['tv', 'desk'],
#  ['two', 'beds', 'are', 'painting', 'lamp', 'on'],
#  ['yellow', 'bathtub'],
#  ['lamps', 'two', 'blanket'],
#  ['small', 'table'],
#  ['head', 'board', 'window'],
#  ['shoes', 'pair', 'floor'],
#  ['pillow'],
#  ['and', 'with'],
#  ['television', 'chair'],
#  ['oven', 'microwave'],
#  ['yellow', 'blanket'],
#  ['closet', 'desk'],
#  ['television', 'desk', 'chair'],
#  ['microwave', 'small', 'painting', 'hanging'],
#  ['carpet', 'red'],
#  ['cat', 'laying'],
#  ['tv', 'screen', 'flat'],
#  ['couch', 'living', 'television', 'chair'],
#  ['railing', 'porch'],
#  ['blue', 'pillows', 'brown', 'blanket'],
#  ['blue', 'towel'],
#  ['with'],
#  ['two', 'beds', 'are', 'sheets', 'hotel'],
#  ['colorful', 'pink', 'suitcase'],
#  ['this', 'two', 'beds'],
#  ['coffee'],
#  ['toilet', 'mirror', 'sink', 'bathroom'],
#  ['brown', 'bed', 'is'],
#  ['comforter', 'and', 'with', 'is'],
#  ['floral', 'night'],
#  ['corner', 'mirror'],
#  ['and'],
#  ['bathtub', 'hotel', 'in', 'room'],
#  ['outside', 'tree'],
#  ['balcony', 'towels', 'hanging', 'couch'],
#  ['two', 'beds', 'are', 'hotel', 'desk', 'chair'],
#  ['window', 'stall', 'bedroom'],
#  ['beds', 'are', 'picture', 'wall', 'the'],
#  ['quilt'],
#  ['tv', 'screen', 'flat', 'couch'],
#  ['fan', 'beds', 'are'],
#  [],
#  ['laptop', 'beds', 'are', 'the'],
#  ['stall'],
#  ['concrete', 'gray'],
#  ['on'],
#  ['blue', 'painting', 'comforter', 'bed'],
#  ['chairs', 'desk', 'room'],
#  ['luggage'],
#  ['brown', 'blanket'],
#  ['with'],
#  ['dresser', 'sheet', 'black'],
#  ['blue', 'it'],
#  ['mounted', 'television'],
#  ['mirror', 'sink', 'shower', 'bathroom'],
#  ['rug', 'black'],
#  ['them', 'towels'],
#  ['person', 'sitting', 'view'],
#  ['kitchen', 'refrigerator', 'chairs', 'table', 'and'],
#  ['tub', 'toilet', 'sink'],
#  ['roll', 'paper', 'bag'],
#  ['headboard', 'brown', 'blanket'],
#  ['side', 'lamps', 'two', 'with'],
#  ['television', 'desk', 'chair'],
#  ['two', 'beds', 'are', 'mirror', 'hotel'],
#  ['sheets', 'pillows', 'white'],
#  ['sheets', 'arafed', 'hotel', 'pillows'],
#  ['sheet', 'black', 'bag'],
#  ['suitcase', 'the'],
#  ['blue', 'painting'],
#  ['and', 'red', 'with'],
#  ['two', 'window', 'beds', 'are', 'hotel'],
#  ['two', 'beds', 'are', 'lamp', 'on', 'hotel'],
#  [],
#  [],
#  ['headboard', 'brown', 'comforter'],
#  ['small', 'kitchen', 'refrigerator', 'table'],
#  ['picture', 'hanging'],
#  ['mirror', 'bedroom'],
#  ['hotel'],
#  ['animal', 'stuffed'],
#  ['mirror', 'bathtub', 'sink', 'bathroom'],
#  ['brown', 'blanket'],
#  ['stand', 'night', 'brown', 'and'],
#  ['sheets', 'arafed', 'hotel', 'pillows'],
#  ['dining', 'top', 'chairs', 'table'],
#  ['in', 'bed', 'is'],
#  ['mirror', 'sink', 'shower', 'bathroom'],
#  ['purple', 'table', 'comforter'],
#  ['toilet', 'mirror', 'sink', 'bathroom'],
#  ['lamp', 'comforter', 'and', 'with', 'is'],
#  ['framed', 'pictures'],
#  ['cover', 'above', 'mirror'],
#  ['hotel', 'in', 'television', 'room', 'bed'],
#  ['painting', 'mirror', 'in'],
#  ['toilet', 'bathtub', 'bathroom'],
#  ['side', 'either', 'lamps', 'green'],
#  ['wallpapered', 'headboard'],
#  ['two', 'beds', 'are', 'mirror', 'sink'],
#  ['is'],
#  [],
#  ['white', 'and'],
#  ['couch', 'in', 'room', 'bed'],
#  ['towels', 'on'],
#  ['outside', 'city', 'lamp', 'comforter'],
#  ['comforter', 'white', 'bed'],
#  ['marble'],
#  ['picture', 'bathtub'],
#  ['two', 'beds', 'bedroom', 'with'],
#  ['small', 'toilet', 'shower', 'bathroom'],
#  ['in', 'desk', 'room', 'bed'],
#  ['two', 'window', 'beds', 'are', 'hotel'],
#  ['two', 'beds', 'bedroom', 'it', 'in'],
#  ['blue', 'two', 'beds', 'are', 'chair'],
#  ['tv', 'screen', 'flat', 'red'],
#  ['two', 'beds', 'are', 'sheets', 'hotel'],
#  ['in', 'is'],
#  ['lamp', 'television', 'desk'],
#  ['glass', 'door', 'small', 'suitcase'],
#  ['lamps', 'curtain', 'painting'],
#  ['lamp', 'television', 'desk', 'and', 'blanket', 'is'],
#  ['glass', 'green', 'pillow'],
#  ['control', 'remote', 'sheet'],
#  ['sheets', 'arafed', 'pillows', 'bed'],
#  ['fan', 'mirror', 'the'],
#  ['tv', 'small', 'cabinet'],
#  ['arafed', 'couch', 'living', 'room'],
#  ['towels', 'with'],
#  ['above', 'painting', 'hanging'],
#  ['on', 'is'],
#  ['tub', 'curtain', 'shower'],
#  ['small', 'toilet', 'bathtub'],
#  ['laying', 'person', 'herself', 'woman', 'taking'],
#  ['dining', 'small', 'chairs', 'table'],
#  ['backpack', 'pillow'],
#  ['desk', 'and'],
#  ['player', 'golf', 'picture', 'wall', 'the'],
#  ['sheets', 'brown', 'and'],
#  ['gold', 'in', 'and'],
#  ['toilet', 'sink', 'shower', 'bathroom'],
#  ['arafed'],
#  ['tv', 'small'],
#  ['two', 'beds', 'bedroom', 'it', 'television'],
#  ['ceiling', 'from', 'sheet', 'hanging'],
#  ['sheets', 'pillows', 'white'],
#  ['dining', 'chairs', 'table'],
#  ['lamps', 'two', 'brown', 'blanket'],
#  ['large', 'bathtub', 'couch'],
#  ['lamp', 'chair'],
#  ['glass', 'door', 'hanging', 'towel'],
#  ['tub', 'bath', 'large', 'glass', 'door'],
#  ['with'],
#  ['are', 'painting', 'wall', 'the'],
#  ['small', 'television', 'desk', 'chair'],
#  ['stove', 'microwave'],
#  ['sheet', 'it', 'on'],
#  ['in', 'and'],
#  ['view', 'living'],
#  ['tan', 'brown'],
#  ['rack', 'hanging', 'towel'],
#  ['laptop', 'bedroom'],
#  ['the', 'in'],
#  ['made', 'neatly', 'bed'],
#  ['black', 'table', 'coffee', 'couch', 'living'],
#  ['headboard', 'brown'],
#  ['yellow'],
#  ['rug', 'black', 'white'],
#  ['front', 'lit', 'wooden', 'purple', 'bedroom'],
#  ['orange', 'white', 'blanket'],
#  ['are'],
#  ['mirror', 'in'],
#  ['blinds', 'chairs', 'television'],
#  ['blankets', 'lot', 'bed'],
#  ['behind', 'leather', 'quilt'],
#  ['rug', 'pink', 'sheet'],
#  ['hat'],
#  ['piano', 'large', 'is'],
#  ['headboard', 'brown', 'comforter', 'red'],
#  ['lamps', 'brown', 'blanket'],
#  ['hotel', 'in', 'desk', 'room', 'bed'],
#  ['laptop', 'bag', 'on'],
#  ['leading', 'to', 'suitcase'],
#  ['toilet', 'sink', 'bathroom', 'white'],
#  ['sheet', 'it', 'on'],
#  ['orange', 'striped'],
#  ['purple', 'desk', 'and'],
#  ['microwave', 'refrigerator'],
#  ['laptop', 'on', 'comforter'],
#  ['two', 'arafed', 'it', 'on', 'pillows', 'blanket'],
#  ['mirror', 'living'],
#  ['bookcase'],
#  ['balcony', 'and'],
#  ['brown', 'and', 'with', 'is'],
#  ['toilet', 'sink'],
#  ['tub', 'bath', 'to', 'next', 'sitting'],
#  ['suitcase', 'chair'],
#  ['food', 'bag'],
#  ['either'],
#  ['large', 'with'],
#  ['blue', 'chair', 'blanket'],
#  ['two', 'beds', 'are', 'sheets', 'brown'],
#  ['tray', 'large', 'is'],
#  ['tub', 'toilet', 'shower'],
#  ['laptop', 'beds', 'the'],
#  ['in', 'television', 'desk', 'room'],
#  ['lamp', 'blanket'],
#  ['picture', 'wall', 'the', 'comforter'],
#  ['mattress', 'mirror'],
#  ['couch', 'living'],
#  ['arafed', 'hotel', 'desk'],
#  ['toilet', 'it', 'sink', 'bathroom'],
#  ['sheets', 'arafed', 'hotel', 'pillows'],
#  ['rack', 'mirror', 'towel'],
#  ['mirror', 'bathtub', 'sink', 'bathroom'],
#  ['table', 'coffee', 'couch'],
#  ['white'],
#  ['view', 'doorway', 'of', 'couch', 'living'],
#  ['jeans', 'pair', 'blue'],
#  ['headboard', 'brown', 'blanket'],
#  ['towels', 'two', 'beds', 'are', 'on'],
#  ['laptop', 'on', 'hotel'],
#  ['brown', 'blanket', 'red'],
#  ['beds', 'hotel', 'desk', 'chair'],
#  ['side', 'lamp'],
#  ['ceiling', 'fan'],
#  ['small', 'bathtub', 'sink', 'bathroom'],
#  ['yellow', 'arafed', 'pillows', 'blanket'],
#  ['brightly', 'colored', 'curtain'],
#  ['sheets', 'arafed', 'hotel', 'pillows'],
#  ['blue', 'stand', 'blanket'],
#  ['kitchen', 'chairs', 'table'],
#  ['window', 'corner', 'of'],
#  ['towel', 'comforter', 'and', 'is'],
#  ['hotel', 'television', 'desk'],
#  ['made', 'neatly', 'bunk'],
#  ['in', 'desk', 'room', 'bed'],
#  ['tablet'],
#  [],
#  ['hallway', 'it', 'table', 'chair'],
#  ['stand', 'night', 'comforter'],
#  ['bag', 'the', 'shower'],
#  ['window', 'small'],
#  ['fan'],
#  ['bedroom', 'it', 'couch', 'television'],
#  ['brown', 'comforter', 'blanket', 'bed'],
#  ['two', 'beds', 'are', 'sheets', 'hotel'],
#  ['hotel', 'in', 'desk', 'room', 'bed'],
#  ['book', 'small'],
#  ['toilet', 'bathtub', 'sink', 'bathroom'],
#  ['tub', 'mirror', 'sink'],
#  ['bar', 'microwave', 'kitchen'],
#  ['green', 'television'],
#  ['table', 'coffee', 'comforter', 'with'],
#  ['roll', 'paper'],
#  ['two', 'pillows', 'comforter', 'white'],
#  ['toilet', 'sink', 'shower', 'bathroom'],
#  ['sinks', 'brick', 'two'],
#  ['big', 'red'],
#  ['other', 'each'],
#  ['purple'],
#  ['bags', 'watch', 'their', 'holding'],
#  ['canopy', 'red'],
#  ['that', 'bathtub', 'living', 'is'],
#  ['sheet', 'small'],
#  ['two', 'window', 'beds', 'are', 'hotel'],
#  ['fan', 'table'],
#  ['side', 'lamp', 'the', 'comforter'],
#  ['that', 'wall', 'the'],
#  ['screen', 'flat'],
#  ['fan', 'blanket', 'red'],
#  [],
#  ['quilt', 'tub'],
#  ['shower', 'spread', 'and', 'is'],
#  ['sheet', 'it', 'on'],
#  ['hotel', 'in', 'desk', 'room', 'bed'],
#  ['bedspread', 'glass', 'door'],
#  ['city', 'view', 'white'],
#  ['floral', 'comforter'],
#  ['and', 'with'],
#  ['sheets', 'hotel', 'pillows', 'white'],
#  ['ball', 'the'],
#  ['ottoman', 'chair'],
#  ['quilt', 'on'],
#  ['small', 'bedroom', 'chair'],
#  [],
#  ['blue', 'small', 'headboard'],
#  ['printer', 'computer'],
#  ['small', 'kitchen'],
#  ['lid', 'flower', 'lit', 'dimly'],
#  ['mirror', 'desk', 'chair'],
#  ['mounted', 'kitchen', 'wall'],
#  ['television', 'desk'],
#  ['blue', 'blanket'],
#  ['sheets', 'blanket', 'red'],
#  ['mirror', 'comforter', 'white'],
#  ['glass', 'shower'],
#  ['woman', 'of', 'picture'],
#  ['window', 'arafed', 'hotel', 'chair'],
#  ['beds', 'are'],
#  ['mirror', 'chair', 'and', 'with', 'is'],
#  ['painting', 'wall', 'the', 'pillows'],
#  ['in', 'television', 'room', 'bed'],
#  ['rack', 'to', 'next', 'sitting', 'towel'],
#  ['window', 'desk'],
#  ['is'],
#  ['colored', 'bed'],
#  ['person'],
#  ['cat', 'laying', 'sheet', 'on'],
#  ['laptop', 'it'],
#  ['balcony', 'couch', 'television'],
#  ['sheets', 'pillows', 'white'],
#  ['two', 'beds', 'are', 'lamp', 'on', 'hotel'],
#  ['people', 'sitting'],
#  ['blue', 'blanket'],
#  ['toilet', 'it', 'sink', 'bathroom'],
#  ['suitcase', 'desk'],
#  ['view', 'doorway', 'hotel'],
#  ['cat', 'black'],
#  ['toilet', 'bathtub', 'sink', 'bathroom'],
#  ['purple'],
#  ['cabinet', 'lot'],
#  ['sheets', 'hotel'],
#  ['small', 'television', 'desk', 'and', 'is'],
#  ['can', 'trash'],
#  ['brick'],
#  ['sheets', 'comforter', 'white'],
#  ['wooden', 'headboard', 'bathtub'],
#  ['it', 'couch', 'television', 'chair'],
#  ['wallpaper', 'two', 'beds', 'are', 'hotel'],
#  ['headboard', 'arafed', 'blanket', 'red'],
#  ['sheet', 'with', 'is'],
#  ['large', 'mirror', 'bathtub'],
#  ['glass', 'door', 'shower'],
#  ['beds', 'are', 'black', 'blanket', 'red'],
#  ['curtain', 'view', 'of', 'shower'],
#  ['toilet', 'mirror', 'sink', 'bathroom'],
#  ['window', 'chair'],
#  ['headboard', 'black', 'comforter'],
#  ['laptop', 'blue', 'headboard', 'the'],
#  ['mirror', 'bathtub', 'sink', 'bathroom'],
#  ['painting', 'sheets', 'white'],
#  ['small', 'desk'],
#  ['glass', 'standing', 'man'],
#  ['control', 'remote', 'animal', 'stuffed', 'on'],
#  ['edge', 'towel', 'bathtub'],
#  ['chairs', 'table', 'couch', 'living'],
#  ['sheet', 'above'],
#  ['bath', 'curtain', 'to', 'next', 'sitting'],
#  ['stand', 'night', 'arafed', 'and', 'red'],
#  ['black', 'chair'],
#  ['bags', 'many'],
#  ['two', 'beds', 'are', 'hotel'],
#  ['headboard', 'white', 'blanket'],
#  ['floor', 'checkered', 'black'],
#  ['toilet', 'picture', 'wall', 'the', 'on'],
#  ['in', 'television', 'room', 'bed'],
#  ['hotel', 'in', 'desk', 'room', 'bed'],
#  ['written', 'letter', 'paper', 'up', 'close', 'piece'],
#  ['cover', 'red'],
#  ['curtain', 'mirror', 'sink', 'shower'],
#  ['couch', 'living', 'chair'],
#  ['two', 'beds', 'are', 'sheets', 'hotel'],
#  ['lamp', 'wall', 'the', 'brown', 'comforter'],
#  ['sinks', 'tub'],
#  ['small', 'toilet', 'bathtub', 'bathroom'],
#  [],
#  ['chairs'],
#  ['pillows', 'white'],
#  ['pillow', 'white', 'red', 'is'],
#  ['pillows'],
#  ['rack', 'towels', 'hanging', 'towel'],
#  ['toilet', 'it', 'sink', 'bathroom'],
#  ['marble', 'counter'],
#  ['small', 'toilet', 'bathtub', 'shower', 'bathroom'],
#  ['to', 'next', 'sitting', 'suitcase', 'chair'],
#  ['in', 'television', 'room', 'bed'],
#  ['stand', 'night', 'bed'],
#  ['curtain', 'toilet'],
#  ['frame', 'flower', 'of', 'picture'],
#  ['window', 'the', 'in'],
#  ['two', 'arafed', 'it', 'pillows', 'blanket', 'red'],
#  ['it', 'on', 'pillows', 'blanket'],
#  ['from', 'above', 'of'],
#  ['white', 'with'],
#  ['arafed', 'hotel', 'pillows', 'blanket'],
#  ['flag', 'building', 'stall', 'of', 'picture', 'shower'],
#  ['brown'],
#  ['background', 'kitchen'],
#  ['small', 'television', 'desk', 'chair'],
#  ['green', 'living', 'brown', 'blanket'],
#  ['sheets', 'pillows', 'white'],
#  ['mirror', 'it', 'sink', 'bathroom'],
#  ['striped', 'bed'],
#  ['window', 'headboard', 'black'],
#  ['tub', 'bath', 'to', 'next', 'sitting'],
#  ['mat', 'yoga', 'large'],
#  ['stand', 'night', 'green'],
#  ['wooden', 'door', 'hallway', 'floor'],
#  ['reflecting', 'red'],
#  ['vanity'],
#  ['black', 'stall', 'suitcase', 'and'],
#  ['in', 'chair', 'room', 'bed'],
#  ['blue', 'painting'],
#  ['toilet', 'mirror', 'sink', 'bathroom'],
#  ['sitting', 'floor', 'suitcase'],
#  ['window', 'chairs', 'in', 'room'],
#  ['small', 'lamp', 'it', 'pillow'],
#  ['blue', 'two', 'beds', 'are', 'wall'],
#  ['two', 'beds', 'are', 'hotel'],
#  ['sitting', 'suitcase', 'hotel'],
#  ['in', 'desk', 'room', 'bed'],
#  ['lamp', 'comforter', 'white'],
#  ['toilet', 'it', 'sink', 'bathroom'],
#  ['lamps', 'dresser', 'red'],
#  ['chandelier', 'blue', 'bedroom', 'blanket'],
#  ['glass', 'door', 'shower'],
#  ['sheets', 'white'],
#  ['fan', 'small'],
#  ['bathtub', 'brown', 'and', 'is'],
#  ['dresser', 'bedroom', 'television'],
#  ['bathtub', 'blanket', 'red'],
#  ['towels', 'hotel', 'red'],
#  ['small', 'view', 'of', 'bathtub'],
#  ['decor', 'dryer', 'hair'],
#  ['two', 'beds', 'are', 'sheets', 'pillows'],
#  ['small', 'bathtub', 'couch'],
#  ['sheets', 'arafed', 'hotel', 'pillows'],
#  ['control', 'remote', 'towels'],
#  ['painting', 'bathtub'],
#  ['kitchen', 'chairs', 'in'],
#  ['that', 'lamp', 'of', 'picture', 'wall'],
#  ['bedspreads', 'matching'],
#  ['stand', 'light', 'on', 'living'],
#  ['backpack', 'red'],
#  ['chandelier', 'canopy'],
#  ['marble'],
#  ['bag', 'it'],
#  ['magazine', 'tile', 'small'],
#  ['cover', 'above', 'stall'],
#  ['brown', 'comforter', 'chair', 'white'],
#  ['televisions', 'many'],
#  ['on', 'white'],
#  ['dispenser', 'paper', 'toilet'],
#  ['maroon', 'three'],
#  ['tile', 'wall', 'brown'],
#  ['pink', 'sliding'],
#  ['table', 'living', 'brown', 'and'],
#  ['bag', 'suitcase'],
#  ['tiles', 'plan', 'sign', 'up', 'close'],
#  ['control', 'remote'],
#  ['tub', 'coffee', 'living'],
#  ['mirror', 'refrigerator', 'sink'],
#  ['beds', 'are', 'painting', 'wall', 'the'],
#  ['luggage', 'small', 'bag'],
#  ['it', 'on', 'blanket'],
#  ['tub', 'curtains', 'toilet'],
#  ['colorful'],
#  ['comforter', 'chair', 'white'],
#  ['picture', 'arafed'],
#  ['sheet', 'window', 'lamp', 'bed'],
#  ['in', 'desk', 'room', 'bed'],
#  ['curtain', 'shower'],
#  ['stall', 'shower'],
#  ['toilet', 'sink', 'shower', 'bathroom'],
#  ['small', 'toilet', 'bathtub', 'bathroom'],
#  ['blvd', 'says', 'sign', 'up', 'close'],
#  ['side', 'either', 'lamps'],
#  ['curtain', 'green', 'view', 'doorway'],
#  ['stool', 'foot', 'red'],
#  ['leads', 'that', 'glass', 'to'],
#  ['tiled'],
#  ['window', 'beds', 'are', 'mirror'],
#  ['black', 'bedroom'],
#  ['gray', 'microwave', 'maker', 'kitchen', 'coffee'],
#  ['sheets', 'hotel', 'pillows', 'white'],
#  ['window', 'chair'],
#  ['edge', 'it', 'towel'],
#  ['backpack', 'couch', 'red'],
#  ['blue', 'and', 'blanket'],
#  ['and', 'with', 'is'],
#  ['lamp', 'comforter', 'white'],
#  [],
#  ['blankets', 'two', 'beds', 'are', 'red'],
#  ['laptop', 'view', 'of', 'arafed'],
#  ['headboard', 'lamp', 'brown'],
#  ['leading', 'to', 'doorway', 'bedroom'],
#  ['brown', 'and', 'red'],
#  ['closet', 'desk'],
#  ['stand', 'night', 'comforter'],
#  ['two', 'beds', 'are', 'hotel', 'television', 'desk'],
#  ['in', 'with', 'is'],
#  ['green', 'chair'],
#  ['colorful', 'suitcase'],
#  ['above', 'red'],
#  ['lamps', 'arafed', 'brown', 'and'],
#  ['quilt', 'coffee'],
#  ['with'],
#  ['mirror', 'comforter', 'white'],
#  ['toy'],
#  ['wall', 'the', 'in'],
#  ['sheet', 'pillow', 'brown'],
#  ['people', 'dark', 'chairs', 'in'],
#  ['standing', 'woman'],
#  ['flowers', 'out', 'heart', 'made'],
#  ['leading', 'laptop', 'counter', 'to', 'doorway', 'kitchen'],
#  ['pillow', 'brown'],
#  ['glass', 'top', 'small', 'table'],
#  ['in', 'desk', 'room', 'bed'],
#  ['leading', 'to'],
#  ['two', 'beds', 'are', 'sheets', 'hotel'],
#  ['in', 'desk', 'room', 'bed'],
#  ['two', 'beds', 'are', 'hotel', 'desk', 'chair'],
#  ['vase', 'flowers', 'glass'],
#  ['toilet', 'couch', 'sink', 'shower', 'and', 'is'],
#  ['tub', 'couch', 'television'],
#  ['pillow', 'comforter', 'red'],
#  ['leading', 'hallway', 'to', 'living'],
#  ['tv', 'desk', 'chair'],
#  ...]

# %%
# приведем массив слов в строку слов
comms = []

for i in range(len(new_comms)):
    comms.append(', '.join(new_comms[i]))
    
comms[0:10]
# Out:
# ['pillow, brown, blanket, bed',
#  'table, couch, living',
#  'lamp, lot, bedroom, of',
#  'mirror, bathtub, sink, bathroom',
#  'sheets, mirror, arafed, pillows',
#  'corner, cabinet, doorway',
#  'bathtub, shower',
#  'pillows, blanket',
#  'bag, suitcase, it, on',
#  'taking, shining, light, purple']

# %%
hotel_comms = np.array(comms)
np.save('hotel_comms', hotel_comms)
np.save('hotel_keys', np.array(list(book.keys())))
